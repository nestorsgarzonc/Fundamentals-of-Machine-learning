# %% [markdown]
# # Matriz conocimiento de modelos predictivos
#
# Ramas:
# ![image.png](attachment:image.png)

# %% [markdown]
# Machine learning=Una parte es aprendizaje estadistico
# Software engineer= Crea producto final

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Revisar siempre el contexto empresarial
#
# ![image.png](attachment:image.png)
#
# La limpieza de datos puede ser la tarea mas larga
# La modelizacion es la parte mas importante
