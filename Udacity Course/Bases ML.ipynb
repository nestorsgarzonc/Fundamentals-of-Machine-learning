# %% [markdown]
# # Sigmoid function:
# ![image.png](attachment:image.png)
#     The curve is between 0 and 1

# %% [markdown]
# # Backpropagation:
# Is the producto of all the derivates calculated
# ![image.png](attachment:image.png)

# %% [markdown]
# Graficamente pasa esto:
# ![image.png](attachment:image.png)
# Pero cada vez que descendemos va siendo mas complejo ya que cada vez se necesitan mas operaciones y el resultado es menor.

# %% [markdown]
# # Hyperbolic tangent function

# %% [markdown]
# This function is too similar to the sigmoid, the difference is that the range of the funcition es between [-1,1]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Rectified linear unit
# ![image.png](attachment:image.png)
# The value of the function depends of the value of X

# %% [markdown]
# # Multi-layer perceptron
# ![image.png](attachment:image.png)
# This neuronal networks use the ReLU (Rectified linear unit) and a sigmoid function, see the graph of the nodes.

# %% [markdown]
# # Batch vs stochastic gradient descent
#
# The model needs to take a bunch for arrive in the local minimum of the function.
# ![image.png](attachment:image.png)

# %% [markdown]
# In each epoch in the neuronal network the STG (Stochastic Gradient Descent) rove in each nodes
# ![image.png](attachment:image.png)

# %% [markdown]
# # Learning rate
#
# ![image.png](attachment:image.png)
# When the learning rate is small, the time to train the model es very slow.
# If the isn't working well, try decreasing the learning rate

# %% [markdown]
# # Momentum
# Normally with the gradient descent the model can stay in a local minimum, take the average for the previus steps
# ![image.png](attachment:image.png)

# %% [markdown]
# # Error functions
