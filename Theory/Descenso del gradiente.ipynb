# %% [markdown]
# Cuadrados ordinarios esta limitado, por ello se usa el gradient descent, seusa en la mayoria de los sistemas.
# En los cuales hay parametros y **la funcion de coste nos dice cual es el error para cada uno de los parametros**
#
# En una funcion conveza hay un minimo unico, en una concava es lo mismo que la conveza pero con otro signo. Pero hay funciones como esta:
# ![image.png](attachment:image.png)
#     Que tiene minimos locales y globales, se llama no convexa

# %% [markdown]
# Deriva la funcion y se iguala la pendinete a cero, se resuelve la ecuacion para encontrar la pendiente nula.
#
# Pero aparte de los minimos locales tenemos otros problemas como los maximos globales, puntos de inflexion o puntos de silla como estos:
# ![image.png](attachment:image.png)

# %% [markdown]
# Una solucion: descenso del gradiente y tiene que encontrar el minimo en una funcion geometricamente similar a esta:
# ![image.png](attachment:image.png)

# %% [markdown]
# Una funcion de coste es el eje y, que es lo que toca descender y en machine learning se manejan miles o millones de parametros.
#
# Se calculan derivadas parciales las cuales nos dicen la direccion en donde se reduce el error, **el vector que producen las derivadas se llama gradiente**
# ![image.png](attachment:image.png)

# %% [markdown]
# Se repite hasta llegar a la convergencia
# A la funcion de la imagen anterior y aunque hace falta algo elemental y es el ratio de aprendizaje (sesgo o bias) quedando asi y dice que tanto afecta el gradiente en cada iteracion:
# ![image.png](attachment:image.png)

# %% [markdown]
# Ejemplo:
# ![image.png](attachment:image.png)
# Esta es una forma habitual de ver las funciones

# %% [markdown]
# Buscar forma correcta para encontrar un ratio de aprendizaje adecuado.
