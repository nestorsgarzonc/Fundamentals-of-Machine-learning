# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Calculo de derivada parcial
# ![image.png](attachment:image.png)

# %% [markdown]
# Ilustracion grafica de recorrido de un minimo local
# ![image.png](attachment:image.png)
