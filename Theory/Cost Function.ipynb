# %% [markdown]
# La funcion de costo permmite ajustar la linea (clasificacion de los datos de la mejor manera)
#
# Theta0=desplazamiento del eje y
# Theta1=pendiente
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Cost function:
# ![image.png](attachment:image.png)

# %% [markdown]
# # Cost function intuition 1
# Examples:
# ![image.png](attachment:image.png)
# Ajustar

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Cuando la pendiente es 0.5
# ![image.png](attachment:image.png)
