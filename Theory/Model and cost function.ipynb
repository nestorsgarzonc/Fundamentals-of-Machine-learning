# %% [markdown]
# # Model representation

# %% [markdown]
# Regresion lineal
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# m=Numero de ejemplos
# x's=datos de entrada
# y's=datos de salida
#
# En los sets de entrenamiento el x(i), y(i) son el i-esimo ejemplo del set de entrenamiento
#
# h=Hipotesis, es similar a una funcion que entra x, sale y
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# h=ecuacion de la recta

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
